# %% [markdown]
# Classification

# %% [markdown]
# - Logistic Regression
# - Decision Tree
# - K Nearest Neighbors
# - Support Vector Machine
# - Naive Bayes
# - Ensemble Methods
#   - Random Forest
#   - Gradient Boosting
